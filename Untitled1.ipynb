# %% [markdown]
# <a href="https://colab.research.google.com/github/m-3huzaifa1/colab/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/My Drive/lsc-cnn1.zip" -d "/content"
# Out:
# Archive:  /content/drive/My Drive/lsc-cnn1.zip
#    creating: /content/lsc-cnn1/__pycache__/
#   inflating: /content/lsc-cnn1/__pycache__/data_reader.cpython-311.pyc
#   inflating: /content/lsc-cnn1/__pycache__/error_function.cpython-311.pyc
#   inflating: /content/lsc-cnn1/__pycache__/network.cpython-311.pyc
#   inflating: /content/lsc-cnn1/data_reader.py
#    creating: /content/lsc-cnn1/dataset/
#   inflating: /content/lsc-cnn1/error_function.py
#   inflating: /content/lsc-cnn1/error_function.so
#    creating: /content/lsc-cnn1/imagenet_vgg_weights/
#   inflating: /content/lsc-cnn1/imagenet_vgg_weights/conv_finalb.npy
#   inflating: /content/lsc-cnn1/imagenet_vgg_weights/conv_finalW.npy
#   inflating: /content/lsc-cnn1/imagenet_vgg_weights/conv1_1b.npy
#   inflating: /content/lsc-cnn1/imagenet_vgg_weights/conv1_1W.npy
#   inflating: /content/lsc-cnn1/imagenet_vgg_weights/conv1_2b.npy
#   inflating: /content/lsc-cnn1/imagenet_vgg_weights/conv1_2W.npy
# ...

# %%
# !unzip "/content/drive/My Drive/ST_partA.zip" -d "/content/lsc-cnn1/dataset"
# Out:
# Archive:  /content/drive/My Drive/ST_partA.zip
#    creating: /content/lsc-cnn1/dataset/ST_partA/test_data/
#    creating: /content/lsc-cnn1/dataset/ST_partA/test_data/ground-truth/
#  extracting: /content/lsc-cnn1/dataset/ST_partA/test_data/ground-truth/GT_IMG_1.mat
#  extracting: /content/lsc-cnn1/dataset/ST_partA/test_data/ground-truth/GT_IMG_10.mat
#  extracting: /content/lsc-cnn1/dataset/ST_partA/test_data/ground-truth/GT_IMG_100.mat
#  extracting: /content/lsc-cnn1/dataset/ST_partA/test_data/ground-truth/GT_IMG_101.mat
#  extracting: /content/lsc-cnn1/dataset/ST_partA/test_data/ground-truth/GT_IMG_102.mat
#   inflating: /content/lsc-cnn1/dataset/ST_partA/test_data/ground-truth/GT_IMG_103.mat
#   inflating: /content/lsc-cnn1/dataset/ST_partA/test_data/ground-truth/GT_IMG_104.mat
#  extracting: /content/lsc-cnn1/dataset/ST_partA/test_data/ground-truth/GT_IMG_105.mat
#  extracting: /content/lsc-cnn1/dataset/ST_partA/test_data/ground-truth/GT_IMG_106.mat
# ...

# %%
cd lsc-cnn1
# Out:
# /content/lsc-cnn1

# %%
# !python main.py --dataset="parta"
# Out:
# ./dataset/stparta_dotmaps_predscale0.5_rgb_ddcnn++_test_val_30
# In data_reader.__init__: Can't read meta data in ./dataset/stparta_dotmaps_predscale0.5_rgb_ddcnn++_test_val_30; call create_dataset_files.
# {'test': ['./dataset/ST_partA/test_data/images', './dataset/ST_partA/test_data/ground-truth'], 'train': ['./dataset/ST_partA/train_data/images', './dataset/ST_partA/train_data/ground-truth']} <data_reader.DataReader object at 0x7dbc3f442bf0>
# CREATING DATASET...
# In data_reader.create_dataset_files: ./dataset/stparta_dotmaps_predscale0.5_rgb_ddcnn++_test_val_30 does not exists; but created.
# In data_reader.create_dataset_files: ./dataset/stparta_dotmaps_predscale0.5_rgb_ddcnn++_test_val_30/test created.
# In data_reader.create_dataset_files: ./dataset/stparta_dotmaps_predscale0.5_rgb_ddcnn++_test_val_30/train created.
# In data_reader.create_dataset_files: ./dataset/stparta_dotmaps_predscale0.5_rgb_ddcnn++_test_val_30/test_valid created.
# Processing IMG_1.jpg ...
# IMG_1
# ...

# %%
# !python main.py --dataset="parta" --start-epoch=0 --epochs=30
# Out:
# Streaming output truncated to the last 5000 lines.
# tensor(0.1293, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# 103
# tensor(0.0772, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.1896, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.1620, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.1848, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# 104
# tensor(0.1123, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0954, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.1144, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.1161, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# 105
# tensor(0.1131, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.1092, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0843, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0242, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# 106
# tensor(0.1077, device='cuda:0', grad_fn=<NllLoss2DBackward0>)
# ...
